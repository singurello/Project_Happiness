# %%
import pandas as pd
import csv

# %%
unem_csv = pd.read_csv("unemployment_data.csv")

# %%
unem_csv
# Out:
#                                            Data Source  \
# 0                                    Last Updated Date
# 1                                                  NaN
# 2                                         Country Name
# 3                                                Aruba
# 4                                          Afghanistan
# 5                                               Angola
# 6                                              Albania
# 7                                              Andorra
# 8                                           Arab World
# 9                                 United Arab Emirates
# 10                                           Argentina
# 11                                             Armenia
# 12                                      American Samoa
# 13                                 Antigua and Barbuda
# 14                                           Australia
# 15                                             Austria
# ...

# %%
unem_csv = unem_csv.drop([0,1])
unem_csv
# Out:
#                                            Data Source  \
# 2                                         Country Name
# 3                                                Aruba
# 4                                          Afghanistan
# 5                                               Angola
# 6                                              Albania
# 7                                              Andorra
# 8                                           Arab World
# 9                                 United Arab Emirates
# 10                                           Argentina
# 11                                             Armenia
# 12                                      American Samoa
# 13                                 Antigua and Barbuda
# 14                                           Australia
# 15                                             Austria
# 16                                          Azerbaijan
# 17                                             Burundi
# ...

# %%
unem_csv.columns = unem_csv.iloc[0]
unem_csv
# Out:
# 2                                         Country Name  Country Code  \
# 2                                         Country Name  Country Code
# 3                                                Aruba           ABW
# 4                                          Afghanistan           AFG
# 5                                               Angola           AGO
# 6                                              Albania           ALB
# 7                                              Andorra           AND
# 8                                           Arab World           ARB
# 9                                 United Arab Emirates           ARE
# 10                                           Argentina           ARG
# 11                                             Armenia           ARM
# 12                                      American Samoa           ASM
# 13                                 Antigua and Barbuda           ATG
# 14                                           Australia           AUS
# ...

# %%
unem_csv = unem_csv.drop([2])

# %%
unem_csv = unem_csv.set_index(['Country Name'],drop = True)

# %%
unem_csv
# Out:
# 2                                                  Country Code  \
# Country Name
# Aruba                                                       ABW
# Afghanistan                                                 AFG
# Angola                                                      AGO
# Albania                                                     ALB
# Andorra                                                     AND
# Arab World                                                  ARB
# United Arab Emirates                                        ARE
# Argentina                                                   ARG
# Armenia                                                     ARM
# American Samoa                                              ASM
# Antigua and Barbuda                                         ATG
# Australia                                                   AUS
# Austria                                                     AUT
# ...

# %%
unem_csv = unem_csv.drop(unem_csv.columns[1:50], axis =1)
unem_csv
# Out:
# 2                                                  Country Code     2007.0  \
# Country Name
# Aruba                                                       ABW        NaN
# Afghanistan                                                 AFG   2.128000
# Angola                                                      AGO  14.633000
# Albania                                                     ALB  15.966000
# Andorra                                                     AND        NaN
# Arab World                                                  ARB   9.846743
# United Arab Emirates                                        ARE   2.467000
# Argentina                                                   ARG   8.470000
# Armenia                                                     ARM   9.812000
# American Samoa                                              ASM        NaN
# Antigua and Barbuda                                         ATG        NaN
# ...

# %%
unem_csv = unem_csv.loc[["Canada","United States","Mexico","Brazil","Korea, Rep.","Philippines",
                        "China","Cambodia","Germany","Russian Federation","Greece"]]
unem_csv
# Out:
# 2                  Country Code  2007.0  2008.0  2009.0  2010.0  2011.0  \
# Country Name
# Canada                      CAN   6.036   6.137   8.344   8.056   7.511
# United States               USA   4.622   5.784   9.254   9.633   8.949
# Mexico                      MEX   3.628   3.874   5.356   5.303   5.170
# Brazil                      BRA   8.327   7.343   8.522   7.726   6.917
# Korea, Rep.                 KOR   3.200   3.200   3.600   3.700   3.400
# Philippines                 PHL   3.434   3.720   3.858   3.605   3.592
# China                       CHN   4.300   4.600   4.700   4.500   4.500
# Cambodia                    KHM   1.168   1.151   1.281   1.377   1.318
# Germany                     DEU   8.658   7.524   7.742   6.966   5.824
# Russian Federation          RUS   6.002   6.205   8.301   7.369   6.536
# Greece                      GRC   8.396   7.760   9.616  12.713  17.865
#
# 2                      2012.0  2013.0     2014.0     2015.0  2016.0  \
# Country Name
# ...

# %%
unem_csv = unem_csv.reset_index()
# Out:
# 2         Country Name Country Code  2007.0  2008.0  2009.0  2010.0  2011.0  \
# 0               Canada          CAN   6.036   6.137   8.344   8.056   7.511
# 1        United States          USA   4.622   5.784   9.254   9.633   8.949
# 2               Mexico          MEX   3.628   3.874   5.356   5.303   5.170
# 3               Brazil          BRA   8.327   7.343   8.522   7.726   6.917
# 4          Korea, Rep.          KOR   3.200   3.200   3.600   3.700   3.400
# 5          Philippines          PHL   3.434   3.720   3.858   3.605   3.592
# 6                China          CHN   4.300   4.600   4.700   4.500   4.500
# 7             Cambodia          KHM   1.168   1.151   1.281   1.377   1.318
# 8              Germany          DEU   8.658   7.524   7.742   6.966   5.824
# 9   Russian Federation          RUS   6.002   6.205   8.301   7.369   6.536
# 10              Greece          GRC   8.396   7.760   9.616  12.713  17.865
#
# ...

# %%
export = unem_csv.to_csv(r'C:\\Users\\carlo\\Desktop\\UNEM1.csv', index = None, header = True )
