# %%
import pandas as pd
import csv

# %%
gdp_csv = pd.read_csv("GDP.csv", skiprows = 1)

# %%
gdp_csv = gdp_csv.reset_index()
gdp_csv
# Out:
#                                                level_0       level_1  \
# 0                                         Country Name  Country Code
# 1                                                Aruba           ABW
# 2                                          Afghanistan           AFG
# 3                                               Angola           AGO
# 4                                              Albania           ALB
# 5                                              Andorra           AND
# 6                                           Arab World           ARB
# 7                                 United Arab Emirates           ARE
# 8                                            Argentina           ARG
# 9                                              Armenia           ARM
# 10                                      American Samoa           ASM
# 11                                 Antigua and Barbuda           ATG
# 12                                           Australia           AUS
# ...

# %%
gdp_csv.columns = gdp_csv.iloc[0]
gdp_csv
# Out:
# 0                                         Country Name  Country Code  \
# 0                                         Country Name  Country Code
# 1                                                Aruba           ABW
# 2                                          Afghanistan           AFG
# 3                                               Angola           AGO
# 4                                              Albania           ALB
# 5                                              Andorra           AND
# 6                                           Arab World           ARB
# 7                                 United Arab Emirates           ARE
# 8                                            Argentina           ARG
# 9                                              Armenia           ARM
# 10                                      American Samoa           ASM
# 11                                 Antigua and Barbuda           ATG
# 12                                           Australia           AUS
# ...

# %%
gdp_csv = gdp_csv.drop([0])
gdp_csv
# Out:
# 0                                         Country Name Country Code  \
# 1                                                Aruba          ABW
# 2                                          Afghanistan          AFG
# 3                                               Angola          AGO
# 4                                              Albania          ALB
# 5                                              Andorra          AND
# 6                                           Arab World          ARB
# 7                                 United Arab Emirates          ARE
# 8                                            Argentina          ARG
# 9                                              Armenia          ARM
# 10                                      American Samoa          ASM
# 11                                 Antigua and Barbuda          ATG
# 12                                           Australia          AUS
# 13                                             Austria          AUT
# ...

# %%
gdp_csv = gdp_csv.drop(gdp_csv.columns[2:51], axis =1 )
gdp_csv
# Out:
# 0                                         Country Name Country Code  \
# 1                                                Aruba          ABW
# 2                                          Afghanistan          AFG
# 3                                               Angola          AGO
# 4                                              Albania          ALB
# 5                                              Andorra          AND
# 6                                           Arab World          ARB
# 7                                 United Arab Emirates          ARE
# 8                                            Argentina          ARG
# 9                                              Armenia          ARM
# 10                                      American Samoa          ASM
# 11                                 Antigua and Barbuda          ATG
# 12                                           Australia          AUS
# 13                                             Austria          AUT
# ...
